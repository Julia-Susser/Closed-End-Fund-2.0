# %%
import os
import numpy as np
import pandas as pd
import random

# %%
class AssetOverlap():
    def __init__(self):
        self.readFunds()
        self.readSP500()

        
    def readFunds(self):
        fundDir = os.listdir("../input/funds")
        funds = pd.DataFrame(columns=["Ticker", "ID"])
        for name in fundDir:
            fund = pd.read_csv("../input/funds/"+name, index_col=0)
            name = name.split(".csv")[0]
            
            fund = fund.rename(columns={fund.columns[-1]:"Ticker", "ID.WEIGHTS":name})
            fund = fund[["ID","Ticker",name]]
            fund = fund[(fund.Ticker.str[:4]!="#N/A") & (fund[name]>0)] #no puts so neg percent and #N/A Unclassified: Unable to parse request at ...  and # N/A Invalid Security
            fund = fund.dropna(axis=0, how='all')
            
            fund[name] = fund[name]/(fund[name].sum())*100 # some have over 100 percent
            
            fund.Ticker = fund.Ticker.fillna("NULL TICKER"+fund.ID)
            
            fund = fund.groupby(["Ticker","ID"]).agg({name:"sum"})# you have to groupby id and ticker or else it may merge multipletimes
            
            funds = funds.merge(fund, how='outer', on=["Ticker","ID"])
        
        
        params = {fundName:"sum" for fundName in self.getFundNames(funds)}
        params.update({"ID":lambda IDS: IDS.iloc[np.argmax([np.all([not char.isdigit() for char in ID]) for ID in IDS])] }) #first id that is all characters or first id
        funds = funds.groupby("Ticker").agg(params)
        funds = funds.reset_index()

        #print(funds.Ticker.duplicated().sum())
        
        funds = funds.fillna(0)
        self.funds = funds

    def getFundMatrix(self):
        return self.funds.loc[:,~self.funds.columns.isin(["ID","Ticker"])]
    
    def readSP500(self):
        self.sp500 = pd.read_csv("../input/s&p500.csv")
        self.sp500 = self.sp500.iloc[:,:3]
        self.sp500 = self.sp500.rename(columns={"Symbol":"Ticker", "Weight":"S&P500"})
        
    def getFundNames(self,funds):
        return [x for x in funds.columns if x not in ["ID", "Ticker"]]
    
    def makePortfolio(self,weights):
        #self.weights = self.weights.loc[self.getFundNames(self.funds)]
        columns = ["Ticker","ID"] + list(weights.index)
        self.funds = self.funds[columns]

        Portfolio = self.getFundMatrix().dot(weights)
        Portfolio = Portfolio.rename({Portfolio.columns[0]:"Portfolio"},axis=1)
        Portfolio[["Ticker","ID"]] = self.funds[["Ticker","ID"]]
        
        Portfolio = pd.merge(Portfolio, self.sp500, how='outer', on="Ticker")
        Portfolio.ID = Portfolio.ID.fillna(Portfolio.Company)
        Portfolio = Portfolio.drop("Company", axis=1)
        return Portfolio
    
    def makeAddStocksPortfolio(self,Portfolio):
        dif = Portfolio["S&P500"]-Portfolio["Portfolio"] # determine which sp500 assets have more than in the portfolio
        self.extra = Portfolio
        self.extra["Dif"] = dif
        self.extra = self.extra[self.extra.Dif>0][["Ticker","ID","Dif"]]
        self.extra = self.extra.rename(columns={"Dif":"Portfolio"})
        AddStocksPortfolio = pd.concat([Portfolio[["Ticker","ID","Portfolio"]],self.extra],axis=0)
        return AddStocksPortfolio
    
    def simpleOverlap(self,weights):
        Portfolio = self.makePortfolio(weights)
        Portfolio[["Portfolio","S&P500"]] = Portfolio[["Portfolio","S&P500"]].fillna(0)
        overlap = np.minimum(np.array(Portfolio["Portfolio"]),np.array(Portfolio["S&P500"]))
        overlap = overlap.sum()
        total = Portfolio.Portfolio.sum()
        return overlap/total*100
    
    def addStocksOverlap(self,weights):
        Portfolio = self.makePortfolio(weights)
        AddStocksPortfolio = self.makeAddStocksPortfolio(Portfolio)
        return self.sp500["S&P500"].sum()/AddStocksPortfolio.Portfolio.sum()*100
    def addStocksPercentCEF(self,weights):
        Portfolio = self.makePortfolio(weights)
        AddStocksPortfolio = self.makeAddStocksPortfolio(Portfolio)
        return Portfolio.Portfolio.sum()/AddStocksPortfolio.Portfolio.sum()*100
        
    def evaluateAssetOverlap(self,weights):
        return self.simpleOverlap(weights)

# %%
class Discount:
    def __init__(self):
        self.readDiscount()
    def readDiscount(self):
        self.discount = pd.read_csv("../input/Discounts.csv")
        self.discount[["Discount", "52W Discount","Effective","Distribution"]] = self.discount.apply(lambda x: [x["Discount"].strip("%"),x["52W Discount"].strip("%"), x["Effective"].strip("%"), x["Distribution"].strip("%")], axis=1, result_type='expand')
        self.discount = self.discount.replace("--",0)
        self.discount.iloc[:,1:] = self.discount.iloc[:,1:].astype("float")
        
        longterm = self.discount["52W Discount"]-self.discount["Discount"] #max: a pos 52 week is pos, a neg discount is more pos
        longterm = longterm/np.max(longterm) *100# between -inf and 1
        self.discount["longterm"] = longterm
        current = -self.discount["Discount"] # max: a neg discount is pos
        current = current/np.max(-self.discount["Discount"]) * 100 #between -inf and 1
        self.discount["value"] = np.sum([longterm,2*current],axis=0)/3
        self.discount = self.discount.set_index("Ticker")
    
    def getWeightedDiscount(self,weights):
        percentCEF = self.addStocksPercentCEF(weights)/100
        self.discount = self.discount.loc[weights.index]
        weights = np.array(weights).reshape(1,len(weights))
        values = np.array(self.discount.Discount).reshape(len(self.discount),1)
        return percentCEF * np.matmul(weights,values)[0][0]
    
    def evaluateDiscount(self,weights):
        self.discount = self.discount.loc[weights.index]
        weights = np.array(weights).reshape(1,len(weights))
        values = np.array(self.discount.value).reshape(len(self.discount),1)
        
        return np.dot(weights,values)[0][0]

# %%
class TabuSet:
    def inTabuSet(self,option):
        fund1, fund2 = option
        tabuList = [adjustment.getFunds() for adjustment in self.TabuSet[:self.numTabu]]
        return [fund1,fund2] in tabuList or [fund2,fund1] in tabuList

# %%
class Adjustment():
    def __init__(self,fund1,fund2,value,weights):
        self.fund1 = fund1
        self.fund2 = fund2
        self.value = value
        self.weights = weights
    def getValue(self):
        return self.value
    def getWeights(self):
        return self.weights
    def getFunds(self):
        return [self.fund1, self.fund2]

# %%
class runModel(AssetOverlap, Discount,TabuSet):
    def __init__(self):
        self.readFunds()
        self.readSP500()
        self.readDiscount()
        
        self.numOptions = 1
        self.numTabu = 0
        
        N = len(self.getFundNames(self.funds))
        weights = np.random.uniform(0,1.0,(N,1))
        weights = np.divide(weights,np.sum(weights))
        
       

        self.weights = pd.DataFrame(weights,columns=["weights"],index=self.getFundNames(self.funds))
        
        self.possibleFunds = list(self.weights.index)
        self.tracker = {}
        self.TabuSet = []
        #self.findInitialBest()
    
    def Evaluate(self,weights):
        asset = .7*(self.evaluateAssetOverlap(weights))
        discount = .3*self.evaluateDiscount(weights)
        return asset+discount
    
    def changeWeights(self,fund1,fund2,weights,change):
        change = min(self.getFundWeight(fund2,weights),change)
        weights.loc[fund1,"weights"] += change
        weights.loc[fund2,"weights"] -= change
        return weights
    
    def EvaluateChange(self,fund1,fund2,weights,change):
        weights = weights.copy()
        weights = self.changeWeights(fund1,fund2,weights,change)
        return self.Evaluate(weights)
    
    def getFundWeight(self,fund,weights):
        return weights.loc[fund][0]
    def findIdealChange(self,fund1,fund2,weights,change):
        control = self.Evaluate(weights)

        while self.EvaluateChange(fund1,fund2,weights,change)>control:
            #print(self.getFundWeight(fund2,weights), self.EvaluateChange(fund1,fund2,weights,change), control)
            self.changeWeights(fund1,fund2,weights,change)
            control = self.Evaluate(weights)
           
            
                
        return control, weights
    
    def makeAdjustment(self,fund1,fund2,weights,change):
        print(fund1, fund2, round(self.getFundWeight(fund1,weights),2),round(self.getFundWeight(fund2,weights),2))
        control = self.Evaluate(weights)
        
        up = self.EvaluateChange(fund1,fund2,weights,change)
        
        down = self.EvaluateChange(fund2,fund1,weights,change)
        print(round(control,2),round(up,2),round(down,2))
        if down>control and down>up:
            fund1, fund2 = fund2, fund1
        elif control>=up: #if down>control but smaller than up that wouldn't make sense so...
#             for fund1,fund in [[fund1,fund2],[fund2,fund1]]:
#                 if self.getFundWeight(fund1,weights)==0 and fund2!=0:
#                     self.tracker[fund1] = self.tracker.get(fund1,0)+1
            return control,weights
        
        self.changeWeights(fund1,fund2,weights,change)
        value, weights = self.findIdealChange(fund1,fund2,weights,change)
        
        return value, weights
    def eliminateFunds(self):
        for fund,value in self.tracker.items():
            if value>=3 and fund in self.possibleFunds: 
                self.possibleFunds.remove(fund)
                
    def randomFunds(self):
        fund2 = random.choice(self.possibleFunds)
        fund1 = random.choice(self.possibleFunds)
        
        if self.getFundWeight(fund1,self.weights)==0 and self.getFundWeight(fund2,self.weights)==0: 
            return self.randomFunds()
        return fund1, fund2
    
    def getOption(self,fund1,fund2):
        change = .1
        value, weights = self.makeAdjustment(fund1, fund2, self.weights, .03)
        return Adjustment(fund1=fund1,fund2=fund2,value=value,weights=weights)
    
            
    def runIteration(self):
        options = [self.randomFunds() for x in range(self.numOptions)]
        
        options = list(filter(lambda option: not self.inTabuSet(option),options))
        
        options = [self.getOption(fund1,fund2) for fund1,fund2 in options]
        
        if len(options)<1: return
        bestIndx = np.argmax([option.getValue() for option in options])

        option = options[bestIndx]
        self.weights = option.getWeights()
        self.TabuSet.append(option)
        #self.eliminateFunds()
    
    def printEvaluation(self):
        print("Simple Overlap %.2f" % self.simpleOverlap(self.weights))
        print("Add Stocks Overlap %.2f" % self.addStocksOverlap(self.weights))
        print("Weighted Discount %.2f" % self.getWeightedDiscount(self.weights))
        
    def runModel(self):
        self.printEvaluation()
        
        for x in range(1000):
            self.runIteration()
            self.printEvaluation()
            print("\n\n")

# %%
obj = runModel()
obj.runModel()
# Out:
# Simple Overlap 30.61
# Add Stocks Overlap 61.90
# Weighted Discount -6.03
# EOS BSTZ 0.01 0.02
# 29.41 30.41 28.71
# Simple Overlap 32.31
# Add Stocks Overlap 62.55
# Weighted Discount -5.98
#
#
#
# BGY AGD 0.02 0.03
# 30.41 29.56 30.96
# Simple Overlap 33.00
# Add Stocks Overlap 62.83
# Weighted Discount -6.04
#
#
#
# BUI ETJ 0.05 0.02
# 30.96 29.66 32.47
# Simple Overlap 36.44
# Add Stocks Overlap 64.21
# Weighted Discount -6.15
#
#
#
# RNP CHN 0.03 0.04
# 33.21 33.44 33.01
# Simple Overlap 36.94
# Add Stocks Overlap 64.42
# Weighted Discount -6.08
#
#
#
# BME DSE 0.03 0.03
# 33.5 33.62 33.33
# Simple Overlap 38.54
# Add Stocks Overlap 65.09
# Weighted Discount -5.69
#
#
#
# CLM EOS 0.03 0.03
# 33.62 32.9 34.2
# Simple Overlap 38.59
# Add Stocks Overlap 65.11
# Weighted Discount -5.97
#
#
#
# EOS CII 0.06 0.01
# 34.2 34.15 34.21
# Simple Overlap 38.18
# Add Stocks Overlap 64.94
# Weighted Discount -6.14
#
#
#
# BDJ ETJ 0.03 0.07
# 34.21 33.95 34.05
# Simple Overlap 38.18
# Add Stocks Overlap 64.94
# Weighted Discount -6.14
#
#
#
# BGY AWP 0.0 0.0
# 34.21 34.2 34.21
# Simple Overlap 38.18
# Add Stocks Overlap 64.94
# Weighted Discount -6.14
#
#
#
# RFI BSTZ 0.01 0.0
# 34.21 34.21 34.28
# Simple Overlap 38.17
# Add Stocks Overlap 64.94
# Weighted Discount -6.19
#
#
#
# MIE NFJ 0.04 0.02
# 34.28 33.76 34.95
# Simple Overlap 39.93
# Add Stocks Overlap 65.68
# Weighted Discount -6.12
#
#
#
# CPZ BMEZ 0.01 0.02
# 35.11 35.65 34.91
# Simple Overlap 40.47
# Add Stocks Overlap 65.92
# Weighted Discount -6.29
#
#
#
# BGR EXD 0.01 0.0
# 35.65 35.68 35.49
# Simple Overlap 40.47
# Add Stocks Overlap 65.92
# Weighted Discount -6.30
#
#
#
# DPG NFJ 0.01 0.06
# 35.68 35.03 35.81
# Simple Overlap 40.67
# Add Stocks Overlap 66.01
# Weighted Discount -6.31
#
#
#
# EXD RQI 0.0 0.04
# 35.81 35.91 35.81
# Simple Overlap 40.81
# Add Stocks Overlap 66.07
# Weighted Discount -6.29
#
#
#
# RQI EMO 0.0 0.04
# 35.92 35.38 35.92
# Simple Overlap 40.81
# Add Stocks Overlap 66.07
# Weighted Discount -6.29
#
#
#
# GLQ BME 0.04 0.05
# 35.92 35.45 36.01
# Simple Overlap 42.01
# Add Stocks Overlap 66.59
# Weighted Discount -5.90
#
#
#
# CHN BGR 0.0 0.01
# 36.01 35.79 36.01
# Simple Overlap 42.01
# Add Stocks Overlap 66.59
# Weighted Discount -5.90
#
#
#
# BDJ AOD 0.03 0.03
# 36.01 36.1 35.71
# Simple Overlap 42.30
# Add Stocks Overlap 66.72
# Weighted Discount -5.83
#
#
#
# AWP AGD 0.0 0.05
# 36.1 35.58 36.14
# Simple Overlap 42.35
# Add Stocks Overlap 66.75
# Weighted Discount -5.83
#
#
#
# NFJ CEN 0.07 0.01
# 36.14 36.19 35.92
# Simple Overlap 42.61
# Add Stocks Overlap 66.86
# Weighted Discount -5.79
#
#
#
# RQI STK 0.0 0.02
# 36.19 35.57 36.19
# Simple Overlap 42.61
# Add Stocks Overlap 66.86
# Weighted Discount -5.79
#
#
#
# ETJ ADX 0.07 0.03
# 36.19 35.4 36.92
# Simple Overlap 42.83
# Add Stocks Overlap 66.96
# Weighted Discount -6.60
#
#
#
# AIO RFI 0.0 0.0
# 37.65 37.65 37.61
# Simple Overlap 42.83
# Add Stocks Overlap 66.96
# Weighted Discount -6.60
#
#
#
# EOI EXD 0.0 0.04
# 37.65 39.09 37.45
# Simple Overlap 45.31
# Add Stocks Overlap 68.09
# Weighted Discount -6.69
#
#
#
# SRV CII 0.0 0.04
# 39.37 38.76 39.39
# Simple Overlap 45.35
# Add Stocks Overlap 68.11
# Weighted Discount -6.68
#
#
#
# ASA EOI 0.0 0.04
# 39.39 38.3 39.46
# Simple Overlap 45.48
# Add Stocks Overlap 68.17
# Weighted Discount -6.67
#
#
#
# BCX BIF 0.02 0.03
# 39.46 38.77 39.72
# Simple Overlap 45.76
# Add Stocks Overlap 68.30
# Weighted Discount -6.72
#
#
#
# IGR RQI 0.0 0.0
# 39.72 39.72 39.68
# Simple Overlap 45.76
# Add Stocks Overlap 68.30
# Weighted Discount -6.72
#
#
#
# SZC CTR 0.04 0.01
# 39.72 39.79 39.48
# Simple Overlap 45.82
# Add Stocks Overlap 68.33
# Weighted Discount -6.75
#
#
#
# CEM UTF 0.02 0.04
# 39.79 40.5 39.22
# Simple Overlap 45.59
# Add Stocks Overlap 68.22
# Weighted Discount -7.31
#
#
#
# ADX ADX 0.09 0.09
# 40.64 40.64 40.64
# Simple Overlap 45.59
# Add Stocks Overlap 68.22
# Weighted Discount -7.31
#
#
#
# SZC BUI 0.05 0.0
# 40.64 40.64 39.77
# Simple Overlap 45.59
# Add Stocks Overlap 68.22
# Weighted Discount -7.31
#
#
#
# ETJ SZC 0.0 0.05
# 40.64 40.98 40.64
# Simple Overlap 48.29
# Add Stocks Overlap 69.50
# Weighted Discount -6.48
#
#
#
# AGD CPZ 0.06 0.03
# 41.03 40.81 41.09
# Simple Overlap 48.25
# Add Stocks Overlap 69.48
# Weighted Discount -6.50
#
#
#
# IAF AGD 0.05 0.03
# 41.09 40.49 41.63
# Simple Overlap 49.45
# Add Stocks Overlap 70.07
# Weighted Discount -6.57
#
#
#
# BIF AOD 0.04 0.0
# 41.89 41.9 41.64
# Simple Overlap 49.44
# Add Stocks Overlap 70.06
# Weighted Discount -6.58
#
#
#
# CRF IGR 0.0 0.0
# 41.9 41.91 41.89
# Simple Overlap 49.59
# Add Stocks Overlap 70.14
# Weighted Discount -6.53
#
#
#
# DPG GRF 0.0 0.0
# 41.91 41.89 41.91
# Simple Overlap 49.59
# Add Stocks Overlap 70.14
# Weighted Discount -6.53
#
#
#
# SZC DNP 0.0 0.01
# 41.91 42.0 41.91
# Simple Overlap 49.41
# Add Stocks Overlap 70.05
# Weighted Discount -6.72
#
#
#
# STK CEM 0.02 0.06
# 42.0 42.48 41.57
# Simple Overlap 51.63
# Add Stocks Overlap 71.16
# Weighted Discount -6.05
#
#
#
# CEM EMO 0.0 0.04
# 42.7 42.5 42.7
# Simple Overlap 51.63
# Add Stocks Overlap 71.16
# Weighted Discount -6.05
#
#
#
# BSTZ ADX 0.01 0.09
# 42.7 41.12 43.14
# Simple Overlap 52.17
# Add Stocks Overlap 71.43
# Weighted Discount -6.12
#
#
#
# ADX BCX 0.1 0.0
# 43.14 43.14 41.98
# Simple Overlap 52.17
# Add Stocks Overlap 71.43
# Weighted Discount -6.12
#
#
#
# CEM CET 0.0 0.03
# 43.14 42.34 43.14
# Simple Overlap 52.17
# Add Stocks Overlap 71.43
# Weighted Discount -6.12
#
#
#
# DPG BOE 0.0 0.0
# 43.14 43.08 43.14
# Simple Overlap 52.17
# Add Stocks Overlap 71.43
# Weighted Discount -6.12
#
#
#
# CII CRF 0.04 0.0
# 43.14 43.19 42.5
# Simple Overlap 52.11
# Add Stocks Overlap 71.40
# Weighted Discount -6.17
#
#
#
# BUI BIF 0.0 0.05
# 43.19 42.15 43.19
# Simple Overlap 52.11
# Add Stocks Overlap 71.40
# Weighted Discount -6.17
#
#
#
# RNP DSE 0.06 0.0
# 43.19 43.19 43.69
# Simple Overlap 51.81
# Add Stocks Overlap 71.24
# Weighted Discount -6.44
#
#
#
# SRV BOE 0.0 0.0
# 43.69 43.62 43.69
# Simple Overlap 51.81
# Add Stocks Overlap 71.24
# Weighted Discount -6.44
#
#
#
# BUI AGD 0.0 0.07
# 43.69 42.86 43.69
# Simple Overlap 51.81
# Add Stocks Overlap 71.24
# Weighted Discount -6.44
#
#
#
# PEO AEF 0.02 0.02
# 43.69 44.29 42.43
# Simple Overlap 52.44
# Add Stocks Overlap 71.57
# Weighted Discount -6.53
#
#
#
# RFI SZC 0.0 0.01
# 44.29 44.04 44.29
# Simple Overlap 52.44
# Add Stocks Overlap 71.57
# Weighted Discount -6.53
#
#
#
# ADX BDJ 0.1 0.06
# 44.29 44.9 43.35
# Simple Overlap 53.49
# Add Stocks Overlap 72.11
# Weighted Discount -6.74
#
#
#
# EMO JEQ 0.04 0.04
# 45.17 45.51 44.84
# Simple Overlap 53.49
# Add Stocks Overlap 72.11
# Weighted Discount -7.00
#
#
#
# BMEZ BME 0.0 0.08
# 45.66 45.67 45.66
# Simple Overlap 52.75
# Add Stocks Overlap 71.73
# Weighted Discount -7.19
#
#
#
# SZC UTF 0.01 0.0
# 45.67 45.67 45.41
# Simple Overlap 52.75
# Add Stocks Overlap 71.73
# Weighted Discount -7.19
#
#
#
# GRF EOI 0.0 0.04
# 45.67 45.84 45.65
# Simple Overlap 52.12
# Add Stocks Overlap 71.41
# Weighted Discount -7.57
#
#
#
# ADX CLM 0.16 0.0
# 45.84 45.84 45.0
# Simple Overlap 52.12
# Add Stocks Overlap 71.41
# Weighted Discount -7.57
#
#
#
# BGR CEN 0.01 0.0
# 45.84 45.84 46.03
# Simple Overlap 52.19
# Add Stocks Overlap 71.44
# Weighted Discount -7.65
#
#
#
# AGD DSE 0.07 0.03
# 46.03 46.0 46.02
# Simple Overlap 52.19
# Add Stocks Overlap 71.44
# Weighted Discount -7.65
#
#
#
# IGR DSE 0.0 0.03
# 46.03 45.73 46.03
# Simple Overlap 52.19
# Add Stocks Overlap 71.44
# Weighted Discount -7.65
#
#
#
# EOI JEQ 0.01 0.0
# 46.03 46.03 45.55
# Simple Overlap 52.19
# Add Stocks Overlap 71.44
# Weighted Discount -7.65
#
#
#
# STK STK 0.07 0.07
# 46.03 46.03 46.03
# Simple Overlap 52.19
# Add Stocks Overlap 71.44
# Weighted Discount -7.65
#
#
#
# GLQ BCX 0.01 0.0
# 46.03 46.03 46.08
# Simple Overlap 52.29
# Add Stocks Overlap 71.49
# Weighted Discount -7.66
#
#
#
# DNP BIF 0.0 0.05
# 46.08 45.46 46.08
# Simple Overlap 52.29
# Add Stocks Overlap 71.49
# Weighted Discount -7.66
#
#
#
# BDJ BME 0.0 0.05
# 46.08 46.98 46.08
# Simple Overlap 52.44
# Add Stocks Overlap 71.57
# Weighted Discount -8.30
#
#
#
# CTR EMO 0.0 0.08
# 47.24 47.15 47.24
# Simple Overlap 52.44
# Add Stocks Overlap 71.57
# Weighted Discount -8.30
#
#
#
# NFJ PEO 0.07 0.04
# 47.24 46.9 46.87
# Simple Overlap 52.44
# Add Stocks Overlap 71.57
# Weighted Discount -8.30
#
#
#
# BCX SZC 0.01 0.01
# 47.24 47.12 47.31
# Simple Overlap 52.42
# Add Stocks Overlap 71.56
# Weighted Discount -8.35
#
#
#
# EOI AOD 0.01 0.0
# 47.31 47.31 47.02
# Simple Overlap 52.42
# Add Stocks Overlap 71.56
# Weighted Discount -8.35
#
#
#
# BMEZ CTR 0.03 0.0
# 47.31 47.31 47.39
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# BSTZ CII 0.0 0.05
# 47.39 46.28 47.39
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# IAF BOE 0.0 0.0
# 47.39 47.27 47.39
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# CRF RNP 0.0 0.03
# 47.39 47.38 47.39
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# IGR CPZ 0.0 0.06
# 47.39 46.88 47.39
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# EMO BGR 0.08 0.0
# 47.39 47.39 47.23
# Simple Overlap 51.96
# Add Stocks Overlap 71.32
# Weighted Discount -8.70
#
#
#
# CPZ NFJ 0.06 0.07
# 47.39 47.13 47.48
# Simple Overlap 52.20
# Add Stocks Overlap 71.44
# Weighted Discount -8.69
#
#
#
# CHN NFJ 0.0 0.1
# 47.48 46.52 47.48
# Simple Overlap 52.20
# Add Stocks Overlap 71.44
# Weighted Discount -8.69
#
#
#
# AGD IAF 0.07 0.0
# 47.48 47.48 47.02
# Simple Overlap 52.20
# Add Stocks Overlap 71.44
# Weighted Discount -8.69
#
#
#
# PEO CTR 0.04 0.03
# 47.48 47.76 46.57
# Simple Overlap 52.66
# Add Stocks Overlap 71.68
# Weighted Discount -8.64
#
#
#
# ETJ AIO 0.05 0.0
# 47.76 47.78 47.21
# Simple Overlap 52.71
# Add Stocks Overlap 71.71
# Weighted Discount -8.63
#
#
#
# EOI CPZ 0.01 0.03
# 47.78 48.09 47.59
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.48
#
#
#
# BIF PEO 0.05 0.07
# 48.09 47.84 47.76
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.48
#
#
#
# NFJ CET 0.1 0.03
# 48.09 47.91 48.27
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# EOS EXD 0.03 0.0
# 48.72 48.72 47.49
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# EOS RFI 0.03 0.0
# 48.72 48.72 47.27
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# ETJ AWP 0.05 0.0
# 48.72 48.72 48.06
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BDJ DPG 0.05 0.0
# 48.72 48.72 48.36
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# DPG AGD 0.0 0.07
# 48.72 48.67 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BME EOI 0.0 0.04
# 48.72 48.07 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# SZC BCX 0.02 0.0
# 48.72 48.72 48.46
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# SZC DNP 0.02 0.0
# 48.72 48.72 48.47
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# JEQ CII 0.0 0.05
# 48.72 47.78 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# DSE AGD 0.03 0.07
# 48.72 48.7 48.7
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BIF IAF 0.05 0.0
# 48.72 48.72 48.07
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# GLQ EMO 0.0 0.08
# 48.72 48.58 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# AIO CET 0.0 0.14
# 48.72 48.18 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# AEF EOI 0.0 0.04
# 48.72 47.61 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BIF UTF 0.05 0.0
# 48.72 48.72 47.62
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# CII EXD 0.05 0.0
# 48.72 48.72 47.67
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# CII DPG 0.05 0.0
# 48.72 48.72 48.22
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# CRF EOS 0.0 0.03
# 48.72 47.96 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# ETJ CRF 0.05 0.0
# 48.72 48.72 48.27
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BUI BIF 0.0 0.05
# 48.72 47.7 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# ADX BCX 0.16 0.0
# 48.72 48.72 47.46
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# CII ASA 0.05 0.0
# 48.72 48.72 48.0
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# EOI RQI 0.04 0.0
# 48.72 48.72 47.46
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# CTR BDJ 0.0 0.05
# 48.72 48.12 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# EOS BUI 0.03 0.0
# 48.72 48.72 47.27
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# JEQ CEN 0.0 0.01
# 48.72 48.47 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# AOD ETJ 0.0 0.05
# 48.72 48.44 48.72
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# BIF CEM 0.05 0.0
# 48.72 48.72 48.17
# Simple Overlap 53.59
# Add Stocks Overlap 72.16
# Weighted Discount -8.93
#
#
#
# ADX EMO 0.16 0.08
# 48.72 49.67 47.68
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# GRF BME 0.03 0.0
# 51.16 51.16 50.16
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# CEN IGR 0.01 0.0
# 51.16 51.16 51.01
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# CEM STK 0.0 0.07
# 51.16 51.02 51.16
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# GRF EXD 0.03 0.0
# 51.16 51.16 49.79
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# DPG BOE 0.0 0.0
# 51.16 51.1 51.16
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# BOE CTR 0.0 0.0
# 51.16 51.16 51.07
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# CHN ADX 0.0 0.24
# 51.16 49.84 51.16
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# SZC JEQ 0.02 0.0
# 51.16 51.16 50.81
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# GRF GLQ 0.03 0.0
# 51.16 51.16 50.1
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# EOI BOE 0.04 0.0
# 51.16 51.14 51.09
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# BIF AIO 0.05 0.0
# 51.16 51.16 50.96
# Simple Overlap 58.37
# Add Stocks Overlap 74.74
# Weighted Discount -8.66
#
#
#
# CII AGD 0.05 0.07
# 51.16 51.35 50.8
# Simple Overlap 59.26
# Add Stocks Overlap 75.24
# Weighted Discount -8.46
#
#
#
# IAF STK 0.0 0.07
# 51.45 51.2 51.45
# Simple Overlap 59.26
# Add Stocks Overlap 75.24
# Weighted Discount -8.46
#
#
#
# GRF AWP 0.03 0.0
# 51.45 51.45 50.34
# Simple Overlap 59.26
# Add Stocks Overlap 75.24
# Weighted Discount -8.46
#
#
#
# CET DPG 0.14 0.0
# 51.45 51.45 51.01
# Simple Overlap 59.26
# Add Stocks Overlap 75.24
# Weighted Discount -8.46
#
#
#
# DSE BIF 0.03 0.05
# 51.45 51.53 51.23
# Simple Overlap 58.89
# Add Stocks Overlap 75.03
# Weighted Discount -8.48
#
#
#
# AGD SZC 0.01 0.02
# 51.53 51.43 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# NFJ SZC 0.0 0.03
# 51.61 51.57 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# GLQ STK 0.0 0.07
# 51.61 51.51 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# ADX JEQ 0.24 0.0
# 51.61 51.61 50.41
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# IGR RNP 0.0 0.03
# 51.61 51.56 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# DNP EOS 0.0 0.03
# 51.61 50.51 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# BUI RNP 0.0 0.03
# 51.61 50.91 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# GLQ PEO 0.0 0.07
# 51.61 51.27 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# CRF BDJ 0.0 0.05
# 51.61 51.18 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# PEO BIF 0.07 0.02
# 51.61 51.29 51.45
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# CEN RFI 0.01 0.0
# 51.61 51.61 51.23
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# PEO PEO 0.07 0.07
# 51.61 51.61 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# BIF AOD 0.02 0.0
# 51.61 51.61 51.43
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# BCX EOI 0.0 0.04
# 51.61 50.62 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# RNP AIO 0.03 0.0
# 51.61 51.61 51.57
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# SZC CHN 0.03 0.0
# 51.61 51.61 50.71
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# AWP CET 0.0 0.14
# 51.61 50.83 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# GLQ EOS 0.0 0.03
# 51.61 50.74 51.61
# Simple Overlap 58.76
# Add Stocks Overlap 74.96
# Weighted Discount -8.59
#
#
#
# BOE ETJ 0.0 0.05
# 51.61 51.65 51.55
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# AEF SZC 0.0 0.03
# 51.65 50.95 51.65
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# BOE BDJ 0.03 0.05
# 51.65 51.53 51.32
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# AWP EOI 0.0 0.04
# 51.65 50.6 51.65
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# ASA BIF 0.0 0.02
# 51.65 51.22 51.65
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# NFJ ADX 0.0 0.24
# 51.65 51.19 51.65
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# BOE EMO 0.03 0.0
# 51.65 51.65 51.16
# Simple Overlap 58.02
# Add Stocks Overlap 74.54
# Weighted Discount -8.91
#
#
#
# ADX PEO 0.24 0.07
# 51.65 52.23 50.83
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# RNP JEQ 0.03 0.0
# 52.23 52.23 51.87
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# EOI BME 0.04 0.0
# 52.23 52.23 51.34
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# BDJ BGY 0.05 0.0
# 52.23 52.23 51.58
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# JEQ SZC 0.0 0.03
# 52.23 51.53 52.23
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# EXD SZC 0.0 0.03
# 52.23 51.41 52.23
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# RNP CEM 0.03 0.0
# 52.23 52.23 52.01
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# CEN EXD 0.01 0.0
# 52.23 52.23 51.93
# Simple Overlap 59.13
# Add Stocks Overlap 75.17
# Weighted Discount -8.90
#
#
#
# STK EMO 0.07 0.0
# 52.23 52.23 52.29
# Simple Overlap 58.30
# Add Stocks Overlap 74.70
# Weighted Discount -9.38
#
#
#
# EOS JEQ 0.03 0.0
# 52.29 52.29 51.19
# Simple Overlap 58.30
# Add Stocks Overlap 74.70
# Weighted Discount -9.38
#
#
#
# STK CPZ 0.04 0.0
# 52.29 52.29 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# SZC ETJ 0.03 0.02
# 52.38 52.18 52.37
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# ETJ JEQ 0.02 0.0
# 52.38 52.38 51.77
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# EOS CEM 0.03 0.0
# 52.38 52.38 51.46
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# RNP AWP 0.03 0.0
# 52.38 52.38 52.35
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# PEO RQI 0.04 0.0
# 52.38 52.38 51.2
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# PEO EXD 0.04 0.0
# 52.38 52.38 51.22
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# SZC JEQ 0.03 0.0
# 52.38 52.38 51.69
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# BSTZ RNP 0.0 0.03
# 52.38 51.94 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# RNP BGR 0.03 0.0
# 52.38 52.38 52.2
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# DPG ADX 0.0 0.27
# 52.38 51.7 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# CTR CEN 0.0 0.01
# 52.38 52.23 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# BUI ADX 0.0 0.27
# 52.38 50.97 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# DNP EOI 0.0 0.04
# 52.38 51.21 52.38
# Simple Overlap 57.88
# Add Stocks Overlap 74.47
# Weighted Discount -9.68
#
#
#
# CII AOD 0.11 0.0
# 52.38 52.38 52.41
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.81
#
#
#
# ETJ ETJ 0.02 0.02
# 52.41 52.41 52.41
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.81
#
#
#
# UTF ADX 0.0 0.27
# 52.41 50.86 52.41
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.81
#
#
#
# AOD CEM 0.03 0.0
# 52.41 52.41 51.94
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.81
#
#
#
# DSE EMO 0.06 0.03
# 52.41 52.55 52.27
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# CPZ BGY 0.03 0.0
# 52.55 52.55 51.95
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# GLQ CII 0.0 0.08
# 52.55 52.11 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# BMEZ EOI 0.0 0.04
# 52.55 51.52 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# BCX STK 0.0 0.01
# 52.55 52.35 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# CHN AOD 0.0 0.03
# 52.55 51.77 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# PEO BUI 0.04 0.0
# 52.55 52.55 51.17
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# AIO CET 0.0 0.14
# 52.55 51.99 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# EOS CTR 0.03 0.0
# 52.55 52.55 51.74
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# PEO EOI 0.04 0.04
# 52.55 51.89 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# DSE AIO 0.09 0.0
# 52.55 52.55 52.41
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# ETJ BIF 0.02 0.02
# 52.55 52.47 52.39
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# BDJ AWP 0.05 0.0
# 52.55 52.55 52.0
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# STK BGR 0.01 0.0
# 52.55 52.55 52.29
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# PEO NFJ 0.04 0.0
# 52.55 52.55 52.19
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# AIO EOS 0.0 0.03
# 52.55 51.84 52.55
# Simple Overlap 57.60
# Add Stocks Overlap 74.31
# Weighted Discount -9.73
#
#
#
# CII CET 0.08 0.14
# 52.55 52.19 52.78
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# EOI EXD 0.04 0.0
# 52.78 52.78 51.48
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# CEN RQI 0.01 0.0
# 52.78 52.78 52.5
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# STK AWP 0.01 0.0
# 52.78 52.78 52.52
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# PEO IGR 0.04 0.0
# 52.78 52.78 51.94
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# AOD AIO 0.03 0.0
# 52.78 52.78 52.49
# Simple Overlap 57.41
# Add Stocks Overlap 74.21
# Weighted Discount -9.98
#
#
#
# CEN CET 0.01 0.17
# 52.78 52.58 52.84
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# BOE EMO 0.03 0.0
# 52.84 52.84 52.32
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# PEO BSTZ 0.04 0.0
# 52.84 52.84 51.68
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# ASA BDJ 0.0 0.05
# 52.84 52.28 52.84
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# IGR DSE 0.0 0.09
# 52.84 52.56 52.84
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# EMO CET 0.0 0.18
# 52.84 52.34 52.84
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# IGR AOD 0.0 0.03
# 52.84 52.45 52.84
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# CPZ EMO 0.03 0.0
# 52.84 52.84 52.58
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# BOE ASA 0.03 0.0
# 52.84 52.84 52.2
# Simple Overlap 57.68
# Add Stocks Overlap 74.35
# Weighted Discount -9.96
#
#
#
# RNP AGD 0.03 0.0
# 52.84 52.84 52.97
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# UTF BIF 0.0 0.02
# 52.97 52.12 52.97
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# GRF BGR 0.03 0.0
# 52.97 52.97 51.89
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# UTF SZC 0.0 0.03
# 52.97 51.93 52.97
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# DNP ADX 0.0 0.27
# 52.97 51.9 52.97
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# DSE EMO 0.09 0.0
# 52.97 52.97 52.83
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# DSE BGR 0.09 0.0
# 52.97 52.97 52.66
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# RFI STK 0.0 0.01
# 52.97 52.49 52.97
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# SZC RNP 0.03 0.0
# 52.97 52.97 52.66
# Simple Overlap 57.49
# Add Stocks Overlap 74.25
# Weighted Discount -10.11
#
#
#
# STK ETJ 0.01 0.02
# 52.97 52.68 53.01
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# ADX CTR 0.27 0.0
# 53.01 53.01 52.15
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# ASA BDJ 0.0 0.05
# 53.01 52.43 53.01
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# GLQ AGD 0.0 0.03
# 53.01 52.72 53.01
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# BIF BGY 0.02 0.0
# 53.01 53.01 52.46
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# UTF AOD 0.0 0.03
# 53.01 52.0 53.01
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# BOE EXD 0.03 0.0
# 53.01 53.01 52.09
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# DNP GRF 0.0 0.03
# 53.01 51.77 53.01
# Simple Overlap 57.72
# Add Stocks Overlap 74.38
# Weighted Discount -10.09
#
#
#
# DSE AOD 0.09 0.03
# 53.01 52.93 53.05
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# SZC RNP 0.03 0.0
# 53.05 53.05 52.73
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# AGD BCX 0.03 0.0
# 53.05 53.05 52.78
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# UTF EOI 0.0 0.04
# 53.05 51.49 53.05
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# MIE PEO 0.0 0.04
# 53.05 52.35 53.05
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# AEF PEO 0.0 0.04
# 53.05 52.02 53.05
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# BMEZ CPZ 0.0 0.03
# 53.05 52.56 53.05
# Simple Overlap 58.40
# Add Stocks Overlap 74.75
# Weighted Discount -10.02
#
#
#
# SZC AOD 0.03 0.06
# 53.05 53.11 52.76
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# NFJ GRF 0.0 0.03
# 53.11 52.46 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# CLM EOS 0.0 0.03
# 53.11 52.48 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# EXD SZC 0.0 0.06
# 53.11 52.41 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# DPG AGD 0.0 0.03
# 53.11 52.99 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# EOS CHN 0.03 0.0
# 53.11 53.11 51.9
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# CPZ IAF 0.03 0.0
# 53.11 53.11 52.52
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# DSE RFI 0.06 0.0
# 53.11 53.11 52.29
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# MIE EOS 0.0 0.03
# 53.11 52.42 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# CTR EOI 0.0 0.04
# 53.11 52.26 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# GLQ BOE 0.0 0.03
# 53.11 52.51 53.11
# Simple Overlap 58.08
# Add Stocks Overlap 74.57
# Weighted Discount -10.21
#
#
#
# CET EOI 0.18 0.04
# 53.11 52.77 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# CHN EOI 0.0 0.07
# 53.21 52.1 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# RFI GRF 0.0 0.03
# 53.21 51.62 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# BCX DSE 0.0 0.06
# 53.21 52.92 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# PEO BOE 0.04 0.03
# 53.21 52.93 52.68
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# BCX EOS 0.0 0.03
# 53.21 52.42 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# BUI ETJ 0.0 0.04
# 53.21 52.26 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# AIO BOE 0.0 0.03
# 53.21 52.72 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# MIE CPZ 0.0 0.03
# 53.21 52.93 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# IGR EOS 0.0 0.03
# 53.21 52.52 53.21
# Simple Overlap 58.85
# Add Stocks Overlap 75.01
# Weighted Discount -9.93
#
#
#
# STK SZC 0.0 0.06
# 53.21 53.25 53.21
# Simple Overlap 59.81
# Add Stocks Overlap 75.55
# Weighted Discount -9.45
#
#
#
# DSE GLQ 0.06 0.0
# 53.25 53.25 52.97
# Simple Overlap 59.81
# Add Stocks Overlap 75.55
# Weighted Discount -9.45
#
#
#
# IAF SZC 0.0 0.03
# 53.25 52.55 53.25
# Simple Overlap 59.81
# Add Stocks Overlap 75.55
# Weighted Discount -9.45
#
#
#
# CII CPZ 0.05 0.03
# 53.25 53.25 52.94
# Simple Overlap 60.19
# Add Stocks Overlap 75.77
# Weighted Discount -9.32
#
#
#
# ETJ UTF 0.04 0.0
# 53.25 53.25 52.22
# Simple Overlap 60.19
# Add Stocks Overlap 75.77
# Weighted Discount -9.32
#
#
#
# ADX AEF 0.27 0.0
# 53.25 53.25 52.2
# Simple Overlap 60.19
# Add Stocks Overlap 75.77
# Weighted Discount -9.32
#
#
#
# ADX CET 0.27 0.15
# 53.25 53.41 52.99
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# BIF BME 0.02 0.0
# 53.41 53.41 53.08
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# CII BSTZ 0.08 0.0
# 53.41 53.41 52.7
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# CLM STK 0.0 0.03
# 53.41 53.03 53.41
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# BCX AOD 0.0 0.03
# 53.41 53.05 53.41
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# BGR STK 0.0 0.03
# 53.41 52.93 53.41
# Simple Overlap 60.68
# Add Stocks Overlap 76.05
# Weighted Discount -9.23
#
#
#
# DSE AOD 0.06 0.03
# 53.41 53.33 53.42
# Simple Overlap 61.29
# Add Stocks Overlap 76.41
# Weighted Discount -9.15
#
#
#
# CET BDJ 0.12 0.05
# 53.42 53.54 52.94
# Simple Overlap 61.10
# Add Stocks Overlap 76.29
# Weighted Discount -9.35
#
#
#
# DSE CEN 0.03 0.0
# 53.54 53.54 53.73
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# JEQ AOD 0.0 0.06
# 53.73 53.25 53.73
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# AEF CEN 0.0 0.03
# 53.73 53.07 53.73
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# RQI CEN 0.0 0.03
# 53.73 53.31 53.73
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# BDJ RQI 0.02 0.0
# 53.73 53.73 53.35
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# BMEZ ETJ 0.0 0.04
# 53.73 53.31 53.73
# Simple Overlap 61.27
# Add Stocks Overlap 76.39
# Weighted Discount -9.45
#
#
#
# EOS STK 0.03 0.03
# 53.73 53.95 53.1
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# CII BUI 0.08 0.0
# 53.95 53.95 52.94
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# EOI SRV 0.07 0.0
# 53.95 53.95 53.55
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# BSTZ AOD 0.0 0.06
# 53.95 53.35 53.95
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# RNP GRF 0.0 0.03
# 53.95 53.11 53.95
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# CTR EOI 0.0 0.07
# 53.95 53.35 53.95
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# GRF BME 0.03 0.0
# 53.95 53.95 52.91
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# CEN AWP 0.03 0.0
# 53.95 53.95 53.55
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# AOD BIF 0.06 0.02
# 53.95 53.74 53.86
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# BDJ JEQ 0.02 0.0
# 53.95 53.95 53.31
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# CEN CRF 0.03 0.0
# 53.95 53.95 53.43
# Simple Overlap 61.82
# Add Stocks Overlap 76.72
# Weighted Discount -9.45
#
#
#
# NFJ AGD 0.0 0.03
# 53.95 54.12 53.95
# Simple Overlap 62.08
# Add Stocks Overlap 76.87
# Weighted Discount -9.47
#
#
#
# GRF MIE 0.03 0.0
# 54.14 54.14 53.33
# Simple Overlap 62.08
# Add Stocks Overlap 76.87
# Weighted Discount -9.47
#
#
#
# AEF NFJ 0.0 0.03
# 54.14 53.56 54.14
# Simple Overlap 62.08
# Add Stocks Overlap 76.87
# Weighted Discount -9.47
#
#
#
# NFJ ADX 0.03 0.3
# 54.14 53.68 54.44
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# MIE GRF 0.0 0.03
# 54.47 53.62 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# AOD CHN 0.06 0.0
# 54.47 54.47 53.78
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# PEO CRF 0.04 0.0
# 54.47 54.47 53.57
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# BIF AOD 0.02 0.06
# 54.47 54.36 54.34
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# UTF CEN 0.0 0.03
# 54.47 53.36 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# BIF CRF 0.02 0.0
# 54.47 54.47 54.17
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# PEO DNP 0.04 0.0
# 54.47 54.47 53.44
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# UTF ADX 0.0 0.34
# 54.47 53.15 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# GLQ SZC 0.0 0.03
# 54.47 53.91 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# EOI AWP 0.07 0.0
# 54.47 54.47 53.96
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# BOE BOE 0.03 0.03
# 54.47 54.47 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# JEQ SZC 0.0 0.03
# 54.47 53.72 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# BSTZ CEN 0.0 0.03
# 54.47 53.69 54.47
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# AOD DSE 0.06 0.0
# 54.47 54.47 54.44
# Simple Overlap 62.55
# Add Stocks Overlap 77.15
# Weighted Discount -9.52
#
#
#
# STK AOD 0.0 0.06
# 54.47 54.6 54.47
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# BSTZ ETJ 0.0 0.04
# 54.6 53.98 54.6
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# CEM PEO 0.0 0.04
# 54.6 53.72 54.6
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# EOS BDJ 0.06 0.02
# 54.6 54.54 54.45
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# PEO RFI 0.04 0.0
# 54.6 54.6 53.21
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# GRF BUI 0.03 0.0
# 54.6 54.6 53.06
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# CET ASA 0.15 0.0
# 54.6 54.6 53.98
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# ADX BSTZ 0.34 0.0
# 54.6 54.6 53.56
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# BDJ EXD 0.02 0.0
# 54.6 54.6 53.93
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# SZC RFI 0.03 0.0
# 54.6 54.6 53.5
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# IGR SZC 0.0 0.03
# 54.6 54.2 54.6
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# SZC BOE 0.03 0.03
# 54.6 54.44 54.19
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# GRF SRV 0.03 0.0
# 54.6 54.6 53.86
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# AWP CII 0.0 0.08
# 54.6 54.31 54.6
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# BDJ CPZ 0.02 0.0
# 54.6 54.6 54.42
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# EOI IAF 0.07 0.0
# 54.6 54.6 53.82
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# NFJ CII 0.0 0.08
# 54.6 54.57 54.6
# Simple Overlap 63.24
# Add Stocks Overlap 77.56
# Weighted Discount -9.23
#
#
#
# EOS BIF 0.06 0.02
# 54.6 54.65 54.18
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -9.00
#
#
#
# BUI ETJ 0.0 0.04
# 54.65 53.75 54.65
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -9.00
#
#
#
# EOI EMO 0.07 0.0
# 54.65 54.65 54.11
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -9.00
#
#
#
# ETJ AIO 0.04 0.0
# 54.65 54.65 54.39
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -9.00
#
#
#
# ADX CRF 0.34 0.0
# 54.65 54.65 53.9
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -9.00
#
#
#
# CET STK 0.15 0.03
# 54.65 54.81 54.11
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# ETJ ETJ 0.04 0.04
# 54.81 54.81 54.81
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# GRF BGR 0.03 0.0
# 54.81 54.81 53.83
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# BMEZ CII 0.0 0.08
# 54.81 54.3 54.81
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# EOS BGY 0.08 0.0
# 54.81 54.81 54.06
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# NFJ EOS 0.0 0.08
# 54.81 54.63 54.81
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# AOD BSTZ 0.03 0.0
# 54.81 54.81 54.16
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# EOS BDJ 0.08 0.02
# 54.81 54.7 54.74
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# BCX BOE 0.0 0.03
# 54.81 54.32 54.81
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# EMO ETJ 0.0 0.04
# 54.81 54.61 54.81
# Simple Overlap 63.36
# Add Stocks Overlap 77.64
# Weighted Discount -9.41
#
#
#
# SZC ETJ 0.03 0.04
# 54.81 54.87 54.39
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# CHN EOI 0.0 0.07
# 54.87 53.65 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# EOS CEM 0.08 0.0
# 54.87 54.87 54.21
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# CET GLQ 0.18 0.0
# 54.87 54.87 54.25
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# CPZ EOS 0.0 0.08
# 54.87 54.65 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# BSTZ GRF 0.0 0.03
# 54.87 53.58 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# EOI CEM 0.07 0.0
# 54.87 54.87 53.96
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# IAF CII 0.0 0.08
# 54.87 54.2 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# CRF AOD 0.0 0.03
# 54.87 54.49 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# AGD ADX 0.0 0.34
# 54.87 54.37 54.87
# Simple Overlap 62.17
# Add Stocks Overlap 76.92
# Weighted Discount -9.97
#
#
#
# CII ADX 0.08 0.34
# 54.87 54.52 55.08
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# AOD BGR 0.03 0.0
# 55.08 55.08 54.73
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# CII CTR 0.05 0.0
# 55.08 55.08 54.42
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# CET RQI 0.18 0.0
# 55.08 55.08 54.52
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# CRF ETJ 0.0 0.01
# 55.08 54.98 55.08
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# BMEZ PEO 0.0 0.04
# 55.08 54.14 55.08
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# RQI CET 0.0 0.18
# 55.08 54.52 55.08
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# ETJ DNP 0.01 0.0
# 55.08 55.08 54.96
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# EOS BDJ 0.08 0.02
# 55.08 54.95 55.07
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# GRF NFJ 0.03 0.0
# 55.08 55.08 54.51
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# CET BUI 0.18 0.0
# 55.08 55.08 53.92
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# BUI BDJ 0.0 0.02
# 55.08 54.2 55.08
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# EOS AEF 0.08 0.0
# 55.08 55.08 54.34
# Simple Overlap 62.21
# Add Stocks Overlap 76.95
# Weighted Discount -10.11
#
#
#
# ETJ BIF 0.01 0.0
# 55.08 55.08 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# CEM CEN 0.0 0.03
# 55.15 54.61 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# GLQ PEO 0.0 0.04
# 55.15 54.27 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# SZC NFJ 0.06 0.0
# 55.15 55.15 55.14
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BGY AOD 0.0 0.03
# 55.15 54.63 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# AIO ADX 0.0 0.37
# 55.15 54.58 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# EOS BCX 0.08 0.0
# 55.15 55.15 54.58
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# CHN BDJ 0.0 0.02
# 55.15 54.38 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# CEN BCX 0.03 0.0
# 55.15 55.15 54.67
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BUI CII 0.0 0.05
# 55.15 53.9 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BOE STK 0.03 0.0
# 55.15 55.15 54.99
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# GRF CHN 0.03 0.0
# 55.15 55.15 53.76
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BUI CEN 0.0 0.03
# 55.15 54.14 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BDJ BMEZ 0.02 0.0
# 55.15 55.15 54.6
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# PEO AIO 0.04 0.0
# 55.15 55.15 54.41
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# BOE GLQ 0.03 0.0
# 55.15 55.15 54.6
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# CII DPG 0.05 0.0
# 55.15 55.15 54.64
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# PEO CEN 0.04 0.03
# 55.15 55.03 54.74
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# ADX EXD 0.37 0.0
# 55.15 55.15 54.14
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# CEM AOD 0.0 0.03
# 55.15 54.75 55.15
# Simple Overlap 62.09
# Add Stocks Overlap 76.88
# Weighted Discount -10.21
#
#
#
# SZC ADX 0.06 0.37
# 55.15 54.79 55.39
# Simple Overlap 63.44
# Add Stocks Overlap 77.68
# Weighted Discount -9.85
#
#
#
# GRF EOS 0.03 0.08
# 55.45 55.5 54.98
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# ADX CPZ 0.43 0.0
# 55.5 55.5 55.24
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# BOE ETJ 0.03 0.0
# 55.5 55.5 55.37
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# CRF GRF 0.0 0.06
# 55.5 54.89 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# GLQ SZC 0.0 0.0
# 55.5 55.49 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# AIO PEO 0.0 0.04
# 55.5 54.75 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# IGR BDJ 0.0 0.02
# 55.5 55.12 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# JEQ CEN 0.0 0.03
# 55.5 54.83 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# AOD JEQ 0.03 0.0
# 55.5 55.5 55.0
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# BDJ ASA 0.02 0.0
# 55.5 55.5 55.01
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# EOS DNP 0.05 0.0
# 55.5 55.5 54.89
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# PEO CRF 0.04 0.0
# 55.5 55.5 54.57
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# AIO SZC 0.0 0.0
# 55.5 55.49 55.5
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# BIF GLQ 0.01 0.0
# 55.5 55.5 55.37
# Simple Overlap 62.30
# Add Stocks Overlap 77.00
# Weighted Discount -10.35
#
#
#
# EOI GRF 0.07 0.06
# 55.5 55.57 55.06
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# IAF ADX 0.0 0.43
# 55.57 54.81 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# CII BOE 0.05 0.03
# 55.57 55.49 55.16
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# AIO BDJ 0.0 0.02
# 55.57 55.17 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# SZC ASA 0.0 0.0
# 55.57 55.57 55.56
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# DNP GRF 0.0 0.03
# 55.57 54.56 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# BDJ BDJ 0.02 0.02
# 55.57 55.57 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# DPG SZC 0.0 0.0
# 55.57 55.57 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# SZC BCX 0.0 0.0
# 55.57 55.57 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# JEQ AOD 0.0 0.03
# 55.57 55.07 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# CHN AOD 0.0 0.03
# 55.57 54.89 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# RQI SZC 0.0 0.0
# 55.57 55.57 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# BCX GRF 0.0 0.03
# 55.57 54.55 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# AOD DNP 0.03 0.0
# 55.57 55.57 55.28
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# CRF CEN 0.0 0.03
# 55.57 55.02 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# GRF MIE 0.03 0.0
# 55.57 55.57 54.71
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# UTF EOS 0.0 0.05
# 55.57 54.51 55.57
# Simple Overlap 63.29
# Add Stocks Overlap 77.59
# Weighted Discount -9.98
#
#
#
# STK BIF 0.0 0.01
# 55.57 55.58 55.57
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# BGY BDJ 0.0 0.02
# 55.58 54.94 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# MIE BOE 0.0 0.03
# 55.58 55.28 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# BUI SZC 0.0 0.0
# 55.58 55.55 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# BDJ CHN 0.02 0.0
# 55.58 55.58 54.8
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# RFI EOI 0.0 0.1
# 55.58 54.34 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CET SRV 0.18 0.0
# 55.58 55.58 55.19
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CEN EOI 0.03 0.1
# 55.58 55.35 55.55
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# BSTZ CET 0.0 0.18
# 55.58 54.66 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# AOD UTF 0.03 0.0
# 55.58 55.58 54.81
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# BIF GRF 0.0 0.03
# 55.58 54.88 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CII ADX 0.05 0.43
# 55.58 55.37 55.54
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# UTF STK 0.0 0.01
# 55.58 55.39 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# IAF PEO 0.0 0.04
# 55.58 54.57 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CII JEQ 0.05 0.0
# 55.58 55.58 54.77
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# ASA CET 0.0 0.18
# 55.58 54.98 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CLM PEO 0.0 0.04
# 55.58 54.72 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# EOS RQI 0.05 0.0
# 55.58 55.58 55.12
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# CHN EOI 0.0 0.1
# 55.58 54.53 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# SZC CRF 0.0 0.0
# 55.58 55.58 55.56
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# AGD CII 0.0 0.05
# 55.58 55.2 55.58
# Simple Overlap 63.43
# Add Stocks Overlap 77.67
# Weighted Discount -9.90
#
#
#
# STK CET 0.01 0.18
# 55.58 55.32 55.6
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# RFI EOI 0.0 0.1
# 55.6 54.37 55.6
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# CLM ADX 0.0 0.43
# 55.6 54.99 55.6
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# IAF SZC 0.0 0.0
# 55.6 55.58 55.6
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# EOI DPG 0.1 0.0
# 55.6 55.6 55.28
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# UTF EOI 0.0 0.1
# 55.6 54.45 55.6
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# ADX CII 0.43 0.05
# 55.6 55.55 55.4
# Simple Overlap 63.30
# Add Stocks Overlap 77.60
# Weighted Discount -9.99
#
#
#
# CPZ CEN 0.0 0.03
# 55.6 55.48 55.6
# Simple Overlap 63.30
# ...
#
#
#
# CET JEQ 0.21 0.0
# 56.05 56.05 55.3
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# SRV ADX 0.0 0.46
# 56.05 55.75 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BDJ GRF 0.05 0.06
# 56.05 55.85 55.81
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# EMO EOS 0.0 0.05
# 56.05 55.6 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# EOS PEO 0.05 0.04
# 56.05 55.63 55.79
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BDJ ASA 0.05 0.0
# 56.05 56.05 55.44
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BCX SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# EXD SZC 0.0 0.0
# 56.05 56.03 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# CII BDJ 0.02 0.05
# 56.05 55.93 55.89
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# CET EOS 0.21 0.05
# 56.05 55.93 55.96
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# ADX AIO 0.46 0.0
# 56.05 56.05 55.55
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# ADX BGR 0.46 0.0
# 56.05 56.05 55.46
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BGR CET 0.0 0.21
# 56.05 55.47 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# IGR SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BIF BDJ 0.0 0.05
# 56.05 55.75 56.05
# Simple Overlap 63.84
# Add Stocks Overlap 77.92
# Weighted Discount -10.21
#
#
#
# BOE CII 0.0 0.02
# 56.05 55.95 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BME EOS 0.0 0.05
# 56.05 55.34 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ BMEZ 0.05 0.0
# 56.05 56.05 55.36
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# ETJ EOS 0.0 0.05
# 56.05 55.57 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CII CPZ 0.02 0.0
# 56.05 56.05 55.84
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CII DPG 0.02 0.0
# 56.05 56.05 55.85
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ CET 0.05 0.21
# 56.05 55.83 55.9
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CII SRV 0.02 0.0
# 56.05 56.05 55.78
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS RNP 0.05 0.0
# 56.05 56.05 55.65
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SRV EOS 0.0 0.05
# 56.05 55.71 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS DSE 0.05 0.0
# 56.05 56.05 55.74
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BSTZ CII 0.0 0.02
# 56.05 55.39 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CPZ EOI 0.0 0.1
# 56.05 55.78 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# STK EOS 0.0 0.05
# 56.05 55.74 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CRF ADX 0.0 0.46
# 56.05 55.4 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# ADX AOD 0.46 0.0
# 56.05 56.05 55.81
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# AGD SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BSTZ EOS 0.0 0.05
# 56.05 55.15 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RNP CET 0.0 0.21
# 56.05 55.7 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI BDJ 0.1 0.05
# 56.05 55.87 55.77
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SRV SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS GRF 0.05 0.06
# 56.05 55.97 55.82
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO CLM 0.04 0.0
# 56.05 56.05 55.12
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI BUI 0.1 0.0
# 56.05 56.05 54.88
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# NFJ PEO 0.0 0.04
# 56.05 55.45 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# AGD CII 0.0 0.02
# 56.05 55.77 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO CRF 0.04 0.0
# 56.05 56.05 55.06
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CRF SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# UTF EOI 0.0 0.1
# 56.05 54.9 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CEN EOI 0.0 0.1
# 56.05 55.88 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO UTF 0.04 0.0
# 56.05 56.05 54.66
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# NFJ CET 0.0 0.21
# 56.05 55.87 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ RFI 0.05 0.0
# 56.05 56.05 54.9
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BCX ADX 0.0 0.46
# 56.05 55.5 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# MIE GRF 0.0 0.06
# 56.05 55.65 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BME EOS 0.0 0.05
# 56.05 55.34 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# IAF GRF 0.0 0.06
# 56.05 55.33 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RNP EOI 0.0 0.1
# 56.05 55.62 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI BGR 0.1 0.0
# 56.05 56.05 55.39
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS CET 0.05 0.21
# 56.05 55.96 55.91
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC GRF 0.0 0.06
# 56.05 56.01 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO CPZ 0.04 0.0
# 56.05 56.05 55.56
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CII DPG 0.02 0.0
# 56.05 56.05 55.85
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CET DSE 0.21 0.0
# 56.05 56.05 55.77
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# AWP CET 0.0 0.21
# 56.05 55.59 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF MIE 0.06 0.0
# 56.05 56.05 55.65
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BMEZ CET 0.0 0.21
# 56.05 55.42 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO ASA 0.04 0.0
# 56.05 56.05 55.2
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO NFJ 0.04 0.0
# 56.05 56.05 55.45
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CEN EOS 0.0 0.05
# 56.05 55.92 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO BUI 0.04 0.0
# 56.05 56.05 54.65
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# MIE EOI 0.0 0.1
# 56.05 55.56 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# AIO CET 0.0 0.21
# 56.05 55.58 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BCX GRF 0.0 0.06
# 56.05 55.51 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EXD CET 0.0 0.21
# 56.05 55.18 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# JEQ EOI 0.0 0.1
# 56.05 55.22 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI EXD 0.1 0.0
# 56.05 56.05 55.1
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS SZC 0.05 0.0
# 56.05 56.05 55.97
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CII EXD 0.02 0.0
# 56.05 56.05 55.39
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EXD EOI 0.0 0.1
# 56.05 55.1 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BUI CET 0.0 0.21
# 56.05 54.96 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF BOE 0.06 0.0
# 56.05 56.05 55.98
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BMEZ CII 0.0 0.02
# 56.05 55.55 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# DPG GRF 0.0 0.06
# 56.05 55.79 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS BOE 0.05 0.0
# 56.05 56.05 55.96
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CTR EOI 0.0 0.1
# 56.05 55.47 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BSTZ SZC 0.0 0.0
# 56.05 56.03 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RFI ADX 0.0 0.46
# 56.05 54.95 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CET STK 0.21 0.0
# 56.05 56.05 55.85
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF BOE 0.06 0.0
# 56.05 56.05 55.98
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS AIO 0.05 0.0
# 56.05 56.05 55.51
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CEM CII 0.0 0.02
# 56.05 55.56 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS JEQ 0.05 0.0
# 56.05 56.05 55.26
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# IGR CII 0.0 0.02
# 56.05 55.69 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# DSE GRF 0.0 0.06
# 56.05 55.78 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# JEQ ADX 0.0 0.46
# 56.05 55.29 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# IAF CII 0.0 0.02
# 56.05 55.49 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# ADX SRV 0.46 0.0
# 56.05 56.05 55.75
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BOE BDJ 0.0 0.05
# 56.05 55.91 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# MIE EOI 0.0 0.1
# 56.05 55.56 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# DPG EOI 0.0 0.1
# 56.05 55.71 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC BDJ 0.0 0.05
# 56.05 55.98 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CET BSTZ 0.21 0.0
# 56.05 56.05 55.19
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RFI EOI 0.0 0.1
# 56.05 54.88 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF SRV 0.06 0.0
# 56.05 56.05 55.76
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GLQ CET 0.0 0.21
# 56.05 55.49 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BSTZ CET 0.0 0.21
# 56.05 55.19 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC BUI 0.0 0.0
# 56.05 56.05 56.03
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO AWP 0.04 0.0
# 56.05 56.05 55.28
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# DSE CII 0.0 0.02
# 56.05 55.79 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BCX BDJ 0.0 0.05
# 56.05 55.45 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO CHN 0.04 0.0
# 56.05 56.05 54.8
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO STK 0.04 0.0
# 56.05 56.05 55.47
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF CII 0.06 0.02
# 56.05 55.87 55.94
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC DSE 0.0 0.0
# 56.05 56.05 56.04
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI IGR 0.1 0.0
# 56.05 56.05 55.53
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC AIO 0.0 0.0
# 56.05 56.05 56.04
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# AIO EOS 0.0 0.05
# 56.05 55.51 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BGR CET 0.0 0.21
# 56.05 55.47 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS CHN 0.05 0.0
# 56.05 56.05 55.07
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS AOD 0.05 0.0
# 56.05 56.05 55.8
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BUI ADX 0.0 0.46
# 56.05 54.95 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CET SRV 0.21 0.0
# 56.05 56.05 55.75
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BUI ADX 0.0 0.46
# 56.05 54.95 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BGR CII 0.0 0.02
# 56.05 55.58 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# PEO RQI 0.04 0.0
# 56.05 56.05 55.3
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# IGR PEO 0.0 0.04
# 56.05 55.3 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CET ADX 0.21 0.46
# 56.05 55.96 55.99
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ EOI 0.05 0.1
# 56.05 55.77 55.87
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BOE EOS 0.0 0.05
# 56.05 55.96 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BSTZ CET 0.0 0.21
# 56.05 55.19 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS BGY 0.05 0.0
# 56.05 56.05 55.28
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI BOE 0.1 0.0
# 56.05 56.05 55.93
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF EXD 0.06 0.0
# 56.05 56.05 55.19
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# NFJ PEO 0.0 0.04
# 56.05 55.45 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ ADX 0.05 0.46
# 56.05 55.83 55.9
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# ETJ SZC 0.0 0.0
# 56.05 56.04 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CEM GRF 0.0 0.06
# 56.05 55.43 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# UTF EOS 0.0 0.05
# 56.05 54.93 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RNP BDJ 0.0 0.05
# 56.05 55.64 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# SZC BGR 0.0 0.0
# 56.05 56.05 56.04
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF CTR 0.06 0.0
# 56.05 56.05 55.55
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# RNP BDJ 0.0 0.05
# 56.05 55.64 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ ASA 0.05 0.0
# 56.05 56.05 55.45
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF SRV 0.06 0.0
# 56.05 56.05 55.76
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ DSE 0.05 0.0
# 56.05 56.05 55.72
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ AWP 0.05 0.0
# 56.05 56.05 55.53
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOI BMEZ 0.1 0.0
# 56.05 56.05 55.34
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# GRF UTF 0.06 0.0
# 56.05 56.05 54.98
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# CEM ADX 0.0 0.46
# 56.05 55.42 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# EOS CRF 0.05 0.0
# 56.05 56.05 55.35
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19
#
#
#
# BDJ BDJ 0.05 0.05
# 56.05 56.05 56.05
# Simple Overlap 63.87
# Add Stocks Overlap 77.94
# Weighted Discount -10.19

# %%
obj.possibleFunds
# Out:
# ['STK',
#  'ADX',
#  'CHN',
#  'MIE',
#  'SZC',
#  'CII',
#  'GRF',
#  'BCX',
#  'CRF',
#  'CEN',
#  'ASA',
#  'AGD',
#  'AIO',
#  'RFI',
#  'BME',
#  'CPZ',
#  'CEM',
#  'BSTZ',
#  'NFJ',
#  'RNP',
#  'EXD',
#  'EOI',
#  'CTR',
#  'GLQ',
#  'BGR',
#  'JEQ',
#  'DSE',
#  'BDJ',
#  'SRV',
#  'CLM',
#  'EMO',
#  'DPG',
#  'AWP',
#  'EOS',
#  'BIF',
#  'ETJ',
#  'IAF',
#  'AOD',
#  'BGY',
#  'BMEZ',
#  'CET',
#  'UTF',
#  'BOE',
#  'IGR',
#  'PEO',
#  'DNP',
#  'RQI',
#  'AEF',
#  'BUI']

# %%
obj.weights.sort_values(by="weights",ascending=False)
# Out:
#        weights
# ADX   0.446655
# CET   0.178057
# EOI   0.097604
# EOS   0.048027
# CII   0.042524
# GRF   0.042143
# PEO   0.041797
# BDJ   0.037430
# SZC   0.021999
# AWP   0.020000
# BOE   0.013763
# SRV   0.010000
# DPG   0.000000
# ETJ   0.000000
# EMO   0.000000
# CLM   0.000000
# BIF   0.000000
# STK   0.000000
# IAF   0.000000
# AOD   0.000000
# BGY   0.000000
# UTF   0.000000
# IGR   0.000000
# DNP   0.000000
# RQI   0.000000
# AEF   0.000000
# BMEZ  0.000000
# BGR   0.000000
# DSE   0.000000
# RFI   0.000000
# CHN   0.000000
# MIE   0.000000
# BCX   0.000000
# CRF   0.000000
# CEN   0.000000
# ASA   0.000000
# AGD   0.000000
# AIO   0.000000
# BME   0.000000
# JEQ   0.000000
# CPZ   0.000000
# CEM   0.000000
# BSTZ  0.000000
# NFJ   0.000000
# RNP   0.000000
# EXD   0.000000
# CTR   0.000000
# GLQ   0.000000
# BUI   0.000000

# %%
Discount().discount
# Out:
#         Effective  Distribution  Discount  52W Discount    longterm      value
# Ticker
# ADX          0.00         20.55    -13.27        -13.74   -4.304029  36.468780
# AEF          7.90          2.64    -12.89        -14.09  -10.989011  33.155048
# AGD          6.94          7.51    -12.70        -13.11   -3.754579  35.023824
# AIO          2.95          5.05     -6.89        -10.25  -30.769231   9.423681
# AOD          0.09          7.84    -13.81        -13.28    4.853480  41.063699
# ASA          0.00          0.09    -15.96        -15.45    4.670330  47.143752
# AWP          7.68          9.28    -12.22        -13.72  -13.736264  30.325558
# BCX          1.20          6.63    -14.22        -15.29   -9.798535  37.350788
# BDJ          0.27          7.19     -9.53         -9.34    1.739927  27.800770
# BGR          0.22          7.88    -13.84         -9.02   44.139194  54.244627
# BGY          0.36          6.99    -10.08        -11.68  -14.652015  23.907769
# BIF          0.36          3.68    -17.19        -16.86    3.021978  50.107583
# BME          0.00          4.93      7.65          1.73  -54.212454 -39.921718
# BMEZ         0.06          4.07     -3.06          0.00   28.021978  18.081019
# BOE          0.00          7.09    -12.33        -12.30    0.274725  35.310084
# BSTZ         0.26          3.83     -6.47         -7.83  -12.454212  14.329030
# BUI          0.13          6.01      3.42          1.45  -18.040293 -15.782069
# CEM         29.27         10.33    -17.60        -17.72   -1.098901  49.905051
# CEN         60.97         26.87    -23.34        -13.78   87.545788  95.848596
# CET          0.32          9.43    -18.61        -17.49   10.256410  56.575044
# CHN          0.10          0.44     -9.55        -13.63  -37.362637  14.823708
# CII          0.10          5.99     -7.00         -8.30  -11.904762  16.026033
# CLM          0.00         19.15     18.47          8.21  -93.956044 -84.075037
# CPZ         30.58          8.17    -14.01        -12.27   15.934066  45.328493
# CRF          9.50         18.94     20.55          9.89  -97.619048 -91.237198
# CTR         19.90         10.09    -20.54        -19.16   12.637363  62.881406
# DNP         26.66          7.52     14.89         19.66   43.681319 -27.970266
# DPG         29.57         12.15    -12.46        -10.69   16.208791  40.992762
# DSE         14.84        113.21    -19.21         -8.29  100.000000  88.203370
# EMO         27.11          8.92    -22.75        -20.25   22.893773  72.612692
# EOI          0.00          6.67     -3.52         -4.23   -6.501832   7.886993
# EOS          0.00          5.50      2.57         -0.67  -29.670330 -17.230870
# ETJ          0.00          8.69      4.37         -0.48  -44.413919 -27.286788
# EXD          0.00          8.49     -4.48         -5.74  -11.538462   8.950190
# GLQ         37.40          9.68    -14.17        -13.15    9.340659  43.587703
# GRF          0.00          7.54    -22.63        -18.83   34.798535  76.238186
# IAF          0.00          9.77    -12.21        -11.10   10.164835  38.264028
# IGR         19.62          8.93    -15.15        -15.43   -2.564103  42.418650
# JEQ          0.00          2.72    -14.25        -16.11  -17.032967  35.025001
# MIE         18.02          7.44    -18.24        -12.00   57.142857  71.147019
# NFJ          0.00          6.77    -12.68        -12.63    0.457875  36.370849
# PEO          0.70         14.84    -17.04        -13.88   28.937729  58.317718
# RFI          1.52          7.23      2.47         -0.37  -26.007326 -15.724236
# RNP         23.99          6.80     -6.09         -8.75  -24.358974   9.275372
# RQI         22.75          7.90     -5.81         -8.78  -27.197802   7.529324
# SRV          3.13          6.37    -22.75        -20.32   22.252747  72.399016
# STK          0.00          6.70      0.80          2.16   12.454212   1.866343
# SZC          3.02          6.89    -23.32        -21.58   15.934066  71.920895
# UTF         27.11          7.21      5.61         -3.19  -80.586081 -42.886020

# %%
def t(ab):
    ab = ab[:]
   
    ab.iloc[0] = [1,3]
    print(ab)
    
    
ki = pd.DataFrame([[1,2]])
t(ki)
ki
#i set the list copy to that and then though I could efdit it after word. but psych apparently that was me editing it and seeting list to something else doesn;t work othersie
# Out:
#    0  1
# 0  1  3
#    0  1
# 0  1  3
